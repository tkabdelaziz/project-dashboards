# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as bs
import requests
import pymongo
import pandas as pd
import time

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.job_db
collection = db.indeed_listings

# %%
#trying Splinter
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
def click_next(browser):
    try:
        browser.is_element_present_by_css(".np")
        browser.find_by_css(".np").click()
    except:
        try:
            browser.find_by_css('#popover-x').click()
        except:
            pass

# %%
titles = ["data+engineer","software+engineer","business+analyst"]

# %%
for title in titles:    
    url = 'https://www.indeed.com/jobs?q={}&l='.format(title)
    browser.visit(url)
    browser.is_text_present('Indeed', wait_time=10)
    
    for x in range(1,1):
        html = browser.html
        soup = bs(html, 'html.parser')

        jobs = soup.find_all('div', id="refineresults")
        job_list = list(jobs)
        postingsummary = {}
        
        for job in job_list:
            try:
            # Identify and return left hand summary of job listing
                salary = job.find('div', id='SALARY_rbo')
                salarieslist = salary.find_all('span', class_='rbLabel').text
                salariescount = salary.find_all('span',class_='rbCount').text
                jobtype = job.find('div',id='JOB_TYPE_rbo')
                jobtypelist = jobtype.find_all('span',class_='rbLabel').text
                jobtypecount = jobtype.find_all('span',class_='rbCount').text
                location = job.find('div',id='LOCATION_rbo')
                locationlist = jobtype.find_all('span',class_='rbLabel').text
                locationcount = jobtype.find_all('span',class_='rbCount').text
                company = job.find('div',id='COMPANY_rbo')
                companylist = jobtype.find_all('span',class_='rbLabel').text
                companycount = jobtype.find_all('span',class_='rbCount').text
                experience = job.find('div',id='EXP_LVL_rbo')
                experiencelist = jobtype.find_all('span',class_='rbLabel').text
                experiencecount = jobtype.find_all('span',class_='rbCount').text
                
                # Run only if title, price, and link are available
                if (salarieslist and jobtypelist and locationlist and companylist and experiencelist):
                # Print results
                    print('-------------')
                    print(salarieslist)
                    print(jobtypelist)
                    print(locationlist)
                    print(companylist)
                    print(experiencelist)

                # Dictionary to be inserted as a MongoDB document
                    post ={
                       'title': title,
                       'company': companylist,
                        'company count':companycount,
                       'salary': salarieslist,
                        'salary count': salariescount,
                        'location': locationlist,
                        'location count': locationcount,
                        'jobtype':jobtypelist,
                        'jobtype count': jobtypecount,
                        'experience level': experiencelist,
                        'experience count':experiencecount
                        }
                    collection.insert_one(post)
                    postingssummary.append(post)
            
            except Exception as e:
                pass

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9414b608df81> in <module>()
# ----> 1 post
#
# NameError: name 'post' is not defined

# %%
for title in titles:
    url = 'https://www.indeed.com/jobs?q={}&l='.format(title)
    browser.visit(url)
    browser.is_text_present('Indeed', wait_time=10)
    
    for x in range(1, 10):
        html = browser.html
        soup = bs(html, 'html.parser')

        jobs = soup.find_all('div', class_="jobsearch-SerpJobCard unifiedRow row result clickcard")
        job_list = list(jobs)
        postings = {}
    
        for job in job_list:
            try:
            # Identify and return job title
                title = job.find('div', class_='title').text
            # Identify and return company name
                company = job.find('span', class_='company').text
            # Identify and return location
                location = job.find('div', class_='location accessible-contrast-color-location').text
            # Identify and return salary
                salary = job.find('span', class_='salaryText').text

            # Run only if title, price, and link are available
                if (title and company and location and salary):
                # Print results
                    print('-------------')
                    print(title)
                    print(company)
                    print(salary)
                    print(location)

                # Dictionary to be inserted as a MongoDB document
                    post ={
                       'title': title,
                       'company': company,
                       'salary': salary,
                        'location': location
                        }
                    collection.insert_one(post)
                    postings.append(post)

            except Exception as e:
                pass
            
        click_next(browser)
# Out:
# -------------
#
#
# Data Engineer
#
#
# Data Crunch
#
# $60,000 - $85,000 a year
# Raleigh-Durham, NC
# -------------
#
#
# Data Science Engineer
#
#
# SteepRock, Inc.
#
# $110,000 - $140,000 a year
# Austin, TX
# -------------
#
#
# Data Engineer
#
#
#
# Central Intelligence Agency
#
# $73,052 - $148,967 a year
# Washington, DC
# -------------
#
#
# Data Engineer
#
#
# Streamline - Real Estate Development
#
# $70,000 - $90,000 a year
# Philadelphia, PA
# -------------
#
#
# Machine Learning Engineer
#
#
# Triplebyte
#
# $125,000 - $190,000 a year
# Seattle, WA
# -------------
#
#
# Entry Level Field Service Engineer
#
#
# Gigaphoton USA, Inc
#
# $45,000 - $50,000 a year
# Austin, TX
# -------------
#
#
# Data Engineer
#
#
#
# Central Intelligence Agency
#
# $73,052 - $148,967 a year
# Washington, DC
# -------------
#
#
# Data Engineer
#
#
# Streamline - Real Estate Development
#
# $70,000 - $90,000 a year
# Philadelphia, PA
# -------------
#
#
# Machine Learning Engineer
#
#
# ...
